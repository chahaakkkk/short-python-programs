# %%
s=["flower","flow","flight"]
print(min(s))
# Out:
# flight

# %%
s=["flower","flow","flight"]
print(min(s,key=len))
# Out:
# flow

# %%
s="abcde"
n=len(s)
for i in range(n):
    print(s)
    s=s[:-1]
# Out:
# abcde
# abcd
# abc
# ab
# a
