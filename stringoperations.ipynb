# %%
s=["flower","flow","flight"]
print(min(s))
# Out:
# flight

# %%
s=["flower","flow","flight"]
print(min(s,key=len))
# Out:
# flow

# %%
s="abcde"
n=len(s)
for i in range(n):
    print(s)
    s=s[:-1]
# Out:
# abcde
# abcd
# abc
# ab
# a

# %%
d={}
s="abcdabc"
for i in s:
    if i in d:
        d[i]=d[i]+1
    else:
        d[i]=1

print(d)
# Out:
# {'a': 2, 'b': 2, 'c': 2, 'd': 1}

# %%
list(filter(lambda x:d[x]>1,d))
# Out:
# ['a', 'b', 'c']
